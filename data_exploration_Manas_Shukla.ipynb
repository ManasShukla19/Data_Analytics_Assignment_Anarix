# %% [markdown]
# # Data Analytics | Python Assignment
#
# ### Name: Manas Shukla
# ### Reg No: 20MIM10003

# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
data = pd.read_csv('Global-Superstore - Global-Superstore.csv')

# %%
# Display the first 5 rows of the dataset
data.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID
# 0   32298   CA-2012-124891   7/31/2012   7/31/2012      Same Day    RH-19495  \
# 1   26341    IN-2013-77878    2/5/2013    2/7/2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  10/17/2013  10/18/2013   First Class    CR-12730
# 3   13524  ES-2013-1579342   1/28/2013   1/30/2013   First Class    KM-16375
# 4   47221     SG-2013-4320   11/5/2013   11/6/2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...
# 0       Rick Hansen     Consumer  New York City         New York  ...  \
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category
# ...

# %%
# Get an overview of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
# Check for missing values
data.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
# Drop the 'Postal Code' column due to missing values
data.drop("Postal Code", axis=1, inplace=True)
data.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
# Check data types and basic statistics
data.dtypes
data.describe()
# Out:
#             Row ID         Sales      Quantity      Discount        Profit
# count  51290.00000  51290.000000  51290.000000  51290.000000  51290.000000  \
# mean   25645.50000    246.490581      3.476545      0.142908     28.610982
# std    14806.29199    487.565361      2.278766      0.212280    174.340972
# min        1.00000      0.444000      1.000000      0.000000  -6599.978000
# 25%    12823.25000     30.758625      2.000000      0.000000      0.000000
# 50%    25645.50000     85.053000      3.000000      0.000000      9.240000
# 75%    38467.75000    251.053200      5.000000      0.200000     36.810000
# max    51290.00000  22638.480000     14.000000      0.850000   8399.976000
#
#        Shipping Cost
# count   51290.000000
# mean       26.375915
# std        57.296804
# min         0.000000
# 25%         2.610000
# 50%         7.790000
# 75%        24.450000
# max       933.570000

# %%
# Total Sales by Market
graph = data.groupby('Market')['Sales'].sum().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
graph.plot(kind='bar')
plt.title('Total Sales by Market')
plt.xlabel('Market')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## This bar plot shows the total sales for each market. APAC has the highest sales, indicating significant market demand.

# %%
# Total Sales by Region
graph = data.groupby('Region')['Sales'].sum().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
graph.plot(kind='bar')
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## This bar plot illustrates total sales by region. The 'Central' region has the highest sales, highlighting a key area for business.

# %%
# Shipping Cost vs Region
graph = data.groupby('Region')['Shipping Cost'].sum().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
graph.plot(kind='bar')
plt.title('Shipping Cost vs Region')
plt.xlabel('Region')
plt.ylabel('Shipping Cost')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## This bar plot shows total shipping costs by region. The 'Central' region incurs the highest shipping costs, potentially due to higher sales volumes.

# %%
# Order Priority Analysis
priority = data['Order Priority'].value_counts()
priority.plot(kind='bar')
plt.title('Order Priority Distribution')
plt.xlabel('Priority Level')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## This bar plot shows the distribution of order priorities. 'Medium' priority orders are the most common.

# %%
# Order Priority Pie Chart
labels = data['Order Priority'].unique()
sizes = data['Order Priority'].value_counts()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Order Priority Distribution (Pie Chart)')
plt.show()

# %% [markdown]
# ## The pie chart provides a visual distribution of order priorities, with 'Medium' priority being the most prevalent.

# %%
# Discount and Profit Analysis
plt.scatter(data['Discount'], data['Profit'])
plt.title('Discount vs. Profit')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ## The scatter plot shows the relationship between discount and profit. A negative correlation indicates higher discounts reduce profit margins.

# %%
# Product Analysis by Sub-Category
products = data.groupby('Sub-Category')['Sales'].sum().sort_values()
sns.barplot(x=products, y=products.index)
plt.title('Total Sales by Sub-Category')
plt.xlabel('Sales')
plt.ylabel('Sub-Category')
plt.show()

# %% [markdown]
# ## This bar plot displays total sales by product sub-category. The 'Phones' sub-category has the highest sales, indicating high demand.

# %%
# Shipping and Delivery Analysis
# Calculate the frequency of each ship mode
ship_mode_counts = data['Ship Mode'].value_counts()
# Calculate the average shipping cost for each ship mode
average_shipping_cost = data.groupby('Ship Mode')['Shipping Cost'].mean()

# Plotting the frequency of ship modes
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)  # 1 row, 2 columns, plot 1
ship_mode_counts.plot(kind='bar', color='lightblue')
plt.title('Frequency of Different Ship Modes')
plt.xlabel('Ship Mode')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

# Plotting the average shipping cost by ship mode
plt.subplot(1, 2, 2)  # 1 row, 2 columns, plot 2
average_shipping_cost.plot(kind='bar', color='lightgreen')
plt.title('Average Shipping Cost by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Average Shipping Cost')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## The first bar plot shows the frequency of different shipping modes, with 'Standard Class' being the most used.
# ## The second bar plot shows average shipping costs, with 'Same Day' shipping being the most expensive.

# %%
# Customer Segmentation
segments = data['Segment'].value_counts()
plt.pie(segments, labels=segments.index, autopct='%1.1f%%', startangle=140)
plt.title('Customer Segment Distribution')
plt.show()

# %% [markdown]
# ## The pie chart shows the distribution of customer segments. 'Consumer' is the largest segment, followed by 'Corporate' and 'Home Office'.

# %%
# Customer Segmentation: Order Counts and Total Sales
order_counts = data['Segment'].value_counts()
total_sales = data.groupby('Segment')['Sales'].sum()

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)  # 1 row, 2 columns, plot 1
order_counts.plot(kind='bar', color='lightblue')
plt.title('Count of Orders by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)  # 1 row, 2 columns, plot 2
total_sales.plot(kind='bar', color='lightgreen')
plt.title('Total Sales by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## The first bar plot shows the number of orders per customer segment, with 'Consumer' segment having the highest number of orders.
# ## The second bar plot shows total sales per segment, with 'Consumer' also generating the highest sales.

# %%
# Correlation Analysis
correlation_matrix = data[['Sales', 'Profit', 'Discount', 'Quantity']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Sales, Profit, Discount, and Quantity')
plt.show()

# %% [markdown]
# ## The heatmap reveals relationships between key variables. Sales and profit have a strong positive correlation, while discount and profit have a negative correlation.

# %%
# Time Series Analysis
data['Order Date'] = pd.to_datetime(data['Order Date'])
monthly_sales = data.resample('M', on='Order Date')['Sales'].sum()

plt.figure(figsize=(14, 7))
plt.plot(monthly_sales)
plt.title('Monthly Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# ## The time series plot shows monthly sales trends over time, highlighting seasonality and growth patterns.

# %% [markdown]
# # Final Interpretation of the Report
#
# ## Data Exploration
#
# 1. Dataset Overview:
#     * Loaded and inspected the dataset to understand its structure and identify any missing values or irrelevant columns. <br><br>
#
# 2. Data Cleaning:
#     * Dropped the 'Postal Code' column due to missing values. <br><br>
#
# 3. Basic Statistics:
#     * Provided descriptive statistics to understand the distribution of numerical variables. <br><br>
#
#
# ## Data Visualization and Analysis
#
# 1. Sales by Market:
#     * Identified APAC as the market with the highest sales. <br><br>
#
# 2. Sales by Region:
#     * Highlighted the 'Central' region as the top-performing region in terms of sales. <br><br>
#
# 3. Shipping Cost vs Region:
#     * Found that the 'Central' region has the highest shipping costs, likely due to higher sales volumes. <br><br>
#
# 4. Order Priority Analysis:
#     * Determined that 'Medium' priority orders are the most common, through bar plots and a pie chart. <br><br>
#
# 5. Discount vs. Profit:
#     * Showed a negative correlation between discounts and profit, suggesting that higher discounts can reduce profit margins. <br><br>
#
# 6. Product Analysis:
#     * Identified 'Phones' as the sub-category with the highest sales. <br><br>
#
# 7. Shipping and Delivery Analysis:
#     * Analyzed shipping modes, finding 'Standard Class' to be the most frequently used and 'Same Day' to be the most expensive. <br><br>
#
# 8. Customer Segmentation:
#     * Found 'Consumer' to be the largest customer segment, both in terms of order count and total sales. <br><br>
#
# 9. Correlation Analysis:
#     * Visualized correlations between key variables, finding strong positive correlations between sales and profit, and negative correlations between discount and profit. <br><br>
#
# 10. Time Series Analysis:
#     * Analyzed monthly sales trends to identify seasonality and growth patterns.
